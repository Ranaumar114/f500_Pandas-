# %%
import pandas as pd

# %%
f500 = pd.read_csv("f500.csv")

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.tail(10)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 490                          National Grid   491     22036            -3.2
# 491                         Dollar General   492     21987             7.9
# 492                         Telecom Italia   493     21941           -17.4
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 490  10150.6   82310          160.2      John Pettigrew
# ...

# %%
f500.shape
# Out:
# (500, 17)

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
f500.iloc[0,11]
# Out:
# 'USA'

# %%
f500.iloc[19,11]
# Out:
# 'Netherlands'

# %%
f500.iloc[19,12]
# Out:
# 'Amsterdam, Netherlands'

# %%
f500["country"]
# Out:
# 0          USA
# 1        China
# 2        China
# 3        China
# 4        Japan
#         ...
# 495     Israel
# 496      China
# 497    Britain
# 498    Germany
# 499        USA
# Name: country, Length: 500, dtype: object

# %%
f500[['country' , 'sector']]
# Out:
#      country                  sector
# 0        USA               Retailing
# 1      China                  Energy
# 2      China                  Energy
# 3      China                  Energy
# 4      Japan  Motor Vehicles & Parts
# ..       ...                     ...
# 495   Israel             Health Care
# 496    China              Financials
# 497  Britain      Food & Drug Stores
# 498  Germany       Business Services
# 499      USA               Retailing
#
# [500 rows x 2 columns]

# %%
f500[['ceo' ,'industry' ,'country']].head()
# Out:
#                    ceo                  industry country
# 0  C. Douglas McMillon     General Merchandisers     USA
# 1              Kou Wei                 Utilities   China
# 2            Wang Yupu        Petroleum Refining   China
# 3        Zhang Jianhua        Petroleum Refining   China
# 4          Akio Toyoda  Motor Vehicles and Parts   Japan

# %%
f500.iloc[[10,11,12], [11,12,13]]
# Out:
#     country        hq_location                           website
# 10      USA  San Francisco, CA           http://www.mckesson.com
# 11  Britain    London, Britain                 http://www.bp.com
# 12      USA     Minnetonka, MN  http://www.unitedhealthgroup.com

# %%
f500.loc[10:15 , ['company' ,'rank']]
# Out:
#                 company  rank
# 10             McKesson    11
# 11                   BP    12
# 12   UnitedHealth Group    13
# 13           CVS Health    14
# 14  Samsung Electronics    15
# 15             Glencore    16

# %%
f500["country"].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
f500["sector"].value_counts()
# Out:
# Financials                       118
# Energy                            80
# Technology                        44
# Motor Vehicles & Parts            34
# Wholesalers                       28
# Health Care                       27
# Food & Drug Stores                20
# Transportation                    19
# Telecommunications                18
# Retailing                         17
# Food, Beverages & Tobacco         16
# Materials                         16
# Industrials                       15
# Aerospace & Defense               14
# Engineering & Construction        13
# Chemicals                          7
# Household Products                 3
# Media                              3
# Hotels, Restaurants & Leisure      3
# Business Services                  3
# Apparel                            2
# Name: sector, dtype: int64

# %%
for chemical, i in f500.iterrows():
    if i["sector"] == 'Chemicals':
        print(i.values)
# Out:
# ['BASF' 126 63641 -18.6 4485.3 80675 1.4 'Kurt W. Bock' 'Chemicals'
#  'Chemicals' 88 'Germany' 'Ludwigshafen, Germany' 'http://www.basf.com' 23
#  109543 33545]
# ['Dow Chemical' 196 48158 -1.3 4318.0 79511 -43.8 'Andrew N. Liveris'
#  'Chemicals' 'Chemicals' 187 'USA' 'Midland, MI' 'http://www.dow.com' 23
#  56000 25987]
# ['ChemChina' 211 45177 9.1 17.9 54341 nan 'Ren Jianxin' 'Chemicals'
#  'Chemicals' 234 'China' 'Beijing, China' 'http://www.chemchina.com' 7
#  110614 3462]
# ['SABIC' 299 35421 -10.3 4757.1 84489 -4.9 'Yousef Abdullah Al-Benyan'
#  'Chemicals' 'Chemicals' 247 'Saudi Arabia' 'Riyadh, Saudi Arabia'
#  'http://www.sabic.com' 13 35000 43471]
# ['Mitsubishi Chemical Holdings' 349 31158 5.6 1442.1 40064 237.1
#  'Hitoshi Ochi' 'Chemicals' 'Chemicals' 324 'Japan' 'Tokyo, Japan'
#  'http://www.mitsubishichem-hd.co.jp' 23 69291 9796]
# ['LyondellBasell Industries' 374 29183 -10.9 3836.0 23442 -14.3
#  'Bhavesh V. Patel' 'Chemicals' 'Chemicals' 315 'Netherlands'
# ...

# %%
for media, i in f500.iterrows():
    if i['sector'] == "Media":
        print(i.values)
# Out:
# ['Disney' 161 55632 6.0 9391.0 92033 12.0 'Robert A. Iger' 'Entertainment'
#  'Media' 164 'USA' 'Burbank, CA' 'http://www.disney.com' 23 195000 43265]
# ['Time Warner' 371 29318 4.3 3926.0 65966 2.4 'Jeffrey L. Bewkes'
#  'Entertainment' 'Media' 376 'USA' 'New York, NY'
#  'http://www.timewarner.com' 16 25000 24335]
# ['Twenty-First Century Fox' 396 27326 -5.7 2755.0 48365 -66.8
#  'James R. Murdoch' 'Entertainment' 'Media' 360 'USA' 'New York, NY'
#  'http://www.21cf.com' 23 21500 13661]

# %%
frq_table = pd.Series()

for i in f500['country']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] += 1

frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\3149793100.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# USA             132
# China           109
# Japan            51
# Germany          29
# Netherlands      14
# Britain          24
# South Korea      15
# Switzerland      14
# France           29
# Taiwan            6
# Singapore         3
# Italy             7
# Russia            4
# Spain             9
# Brazil            7
# Mexico            2
# Luxembourg        1
# India             7
# Malaysia          1
# Thailand          1
# Australia         7
# Belgium           1
# Norway            1
# Canada           11
# Ireland           4
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Sweden            3
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# ...

# %%
for ireland, i in f500.iterrows():
    if i['country'] == "Ireland":
        print(i.values)
# Out:
# ['Johnson Controls International' 272 37674 -6.3 -868.0 63253 -155.5
#  'Alex A. Molinaroli' 'Industrial Machinery' 'Industrials' 0 'Ireland'
#  'Cork, Ireland' 'http://www.johnsoncontrols.com' 13 209000 24118]
# ['Accenture' 305 34798 5.7 4111.9 20609 34.7 'Pierre Nanterme'
#  'Information Technology Services' 'Technology' 312 'Ireland'
#  'Dublin, Ireland' 'http://www.accenture.com' 16 384000 7555]
# ['CRH' 363 29973 14.3 1374.6 33320 71.2 'Albert Manifold'
#  'Building Materials, Glass' 'Materials' 411 'Ireland' 'Dublin, Ireland'
#  'http://www.crh.com' 14 86778 14654]
# ['Medtronic' 377 28833 42.3 3538.0 99782 32.3 'Omar S. Ishrak'
#  'Medical Products and Equipment' 'Health Care' 0 'Ireland'
#  'Dublin, Ireland' 'http://www.medtronic.com' 1 98017 52063]

# %%
frq_table = pd.Series()

for i in f500['sector']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] += 1

frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\2209044672.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# Retailing                         17
# Energy                            80
# Motor Vehicles & Parts            34
# Financials                       118
# Technology                        44
# Wholesalers                       28
# Health Care                       27
# Telecommunications                18
# Engineering & Construction        13
# Industrials                       15
# Food & Drug Stores                20
# Aerospace & Defense               14
# Food, Beverages & Tobacco         16
# Household Products                 3
# Transportation                    19
# Materials                         16
# Chemicals                          7
# Media                              3
# Apparel                            2
# ...

# %%
frq_table = pd.Series()

for i in f500['sector']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] += 1

frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\2209044672.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# Retailing                         17
# Energy                            80
# Motor Vehicles & Parts            34
# Financials                       118
# Technology                        44
# Wholesalers                       28
# Health Care                       27
# Telecommunications                18
# Engineering & Construction        13
# Industrials                       15
# Food & Drug Stores                20
# Aerospace & Defense               14
# Food, Beverages & Tobacco         16
# Household Products                 3
# Transportation                    19
# Materials                         16
# Chemicals                          7
# Media                              3
# Apparel                            2
# ...

# %%
f500
# Out:
# 0        6
# 1        7
# 2        8
# 3        9
# 4       10
#       ...
# 495    501
# 496    502
# 497    503
# 498    504
# 499    505
# Name: rank, Length: 500, dtype: int64

# %%
import pandas as pd

# %%
f500 = pd.read_csv('f500.csv')

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
f500.loc[0:5 , "company" : "ceo"]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
#
#    profit_change                  ceo
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# 2          -65.0            Wang Yupu
# 3          -73.7        Zhang Jianhua
# 4          -12.3          Akio Toyoda
# 5            NaN      Matthias Muller

# %%
f500.loc[3 ,'profits'] += 1000

# %%
f500.loc[3 ,'profits']
# Out:
# 2867.5

# %%
f500['profits'] + 1000
# Out:
# 0      14643.0
# 1      10571.3
# 2       2257.9
# 3       3867.5
# 4      17899.3
#         ...
# 495     1329.0
# 496     1743.9
# 497     1406.4
# 498     2151.7
# 499     1430.5
# Name: profits, Length: 500, dtype: float64

# %%
f500[['ceo' , 'profits']]
# Out:
#                      ceo  profits
# 0    C. Douglas McMillon  13643.0
# 1                Kou Wei   9571.3
# 2              Wang Yupu   1257.9
# 3          Zhang Jianhua   2867.5
# 4            Akio Toyoda  16899.3
# ..                   ...      ...
# 495    Yitzhak Peterburg    329.0
# 496             Wan Feng    743.9
# 497       David T. Potts    406.4
# 498    Friedrich Joussen   1151.7
# 499   Michael J. Jackson    430.5
#
# [500 rows x 2 columns]

# %%
f500.dtypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
bool_usa = f500['country'] == 'USA'
bool_usa
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: country, Length: 500, dtype: bool

# %%
bool_usa
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: country, Length: 500, dtype: bool

# %%
bool_finance = f500['sector'] == 'Financials'

# %%
bool_finance
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496     True
# 497    False
# 498    False
# 499    False
# Name: sector, Length: 500, dtype: bool

# %%
f500["sector"].value_counts()
# Out:
# Financials                       118
# Energy                            80
# Technology                        44
# Motor Vehicles & Parts            34
# Wholesalers                       28
# Health Care                       27
# Food & Drug Stores                20
# Transportation                    19
# Telecommunications                18
# Retailing                         17
# Food, Beverages & Tobacco         16
# Materials                         16
# Industrials                       15
# Aerospace & Defense               14
# Engineering & Construction        13
# Chemicals                          7
# Household Products                 3
# Media                              3
# Hotels, Restaurants & Leisure      3
# Business Services                  3
# Apparel                            2
# Name: sector, dtype: int64

# %%
f500["country"].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
for aus, i in f500.iterrows():
    if i['country'] == "Australia":
        print(i.values)
# Out:
# ['Wesfarmers' 198 48003 -7.6 296.1 30358 -85.4 'Richard J.B. Goyder'
#  'Food and Drug Stores' 'Food & Drug Stores' 171 'Australia'
#  'Perth, Australia' 'http://www.wesfarmers.com.au' 9 220000 17083]
# ['Woolworths' 218 43925 -13.2 -898.3 17495 -150.3 'Brad Banducci'
#  'Food and Drug Stores' 'Food & Drug Stores' 176 'Australia'
#  'Bella Vista, Australia' 'http://www.woolworthslimited.com.au' 21 205000
#  6305]
# ['Commonwealth Bank of Australia' 333 32287 -14.3 6712.9 694565 -10.9
#  'Ian M. Narev' 'Banks: Commercial and Savings' 'Financials' 269
#  'Australia' 'Sydney, Australia' 'http://www.commbank.com.au' 13 45129
#  44816]
# ['BHP Billiton' 350 30912 -40.9 -6385.0 118953 -434.3 'Andrew Mackenzie'
#  'Mining, Crude-Oil Production' 'Energy' 168 'Australia'
#  'Melbourne, Australia' 'http://www.bhpbilliton.com' 23 26827 54290]
# ['Westpac Banking' 391 27704 -10.8 5477.0 642083 -12.7 'Brian C. Hartzer'
#  'Banks: Commercial and Savings' 'Financials' 336 'Australia'
# ...

# %%
f500["country"] == "USA"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: country, Length: 500, dtype: bool

# %%
f500[f500["country"] == 'USA']
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 0               Walmart     1    485873             0.8  13643.0  198825
# 7    Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                 Apple     9    215639            -7.7  45687.0  321686
# 9           Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10             McKesson    11    198533             3.1   5070.0   60969
# ..                  ...   ...       ...             ...      ...     ...
# 480        U.S. Bancorp   481     22744             5.8   5888.0  445964
# 482               Aflac   483     22559             8.1   2659.0  129819
# 488      Sears Holdings   489     22138           -12.0  -2221.0    9362
# 491      Dollar General   492     21987             7.9   1251.1   11672
# 499          AutoNation   500     21609             3.6    430.5   10060
#
#      profit_change                  ceo  \
# 0             -7.2  C. Douglas McMillon
# ...

# %%
f500[f500['country'] == "Australia"]
# Out:
#                                    company  rank  revenues  revenue_change  \
# 197                             Wesfarmers   198     48003            -7.6
# 217                             Woolworths   218     43925           -13.2
# 332         Commonwealth Bank of Australia   333     32287           -14.3
# 349                           BHP Billiton   350     30912           -40.9
# 390                        Westpac Banking   391     27704           -10.8
# 404                National Australia Bank   405     26958           -21.1
# 417  Australia & New Zealand Banking Group   418     26032           -10.1
#
#      profits  assets  profit_change                  ceo  \
# 197    296.1   30358          -85.4  Richard J.B. Goyder
# 217   -898.3   17495         -150.3        Brad Banducci
# 332   6712.9  694565          -10.9         Ian M. Narev
# 349  -6385.0  118953         -434.3     Andrew Mackenzie
# 390   5477.0  642083          -12.7     Brian C. Hartzer
# ...

# %%
bool_finance = f500["sector"] == "Financials"
bool_finance
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496     True
# 497    False
# 498    False
# 499    False
# Name: sector, Length: 500, dtype: bool

# %%
frq_table = pd.Series()

for i in f500['country']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] += 1
        
frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\2940088861.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# USA             132
# China           109
# Japan            51
# Germany          29
# Netherlands      14
# Britain          24
# South Korea      15
# Switzerland      14
# France           29
# Taiwan            6
# Singapore         3
# Italy             7
# Russia            4
# Spain             9
# Brazil            7
# Mexico            2
# Luxembourg        1
# India             7
# Malaysia          1
# Thailand          1
# Australia         7
# Belgium           1
# Norway            1
# Canada           11
# Ireland           4
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Sweden            3
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# ...

# %%
frq_table = pd.Series()

for i in f500['sector']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] +=1

frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\3973756660.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# Retailing                         17
# Energy                            80
# Motor Vehicles & Parts            34
# Financials                       118
# Technology                        44
# Wholesalers                       28
# Health Care                       27
# Telecommunications                18
# Engineering & Construction        13
# Industrials                       15
# Food & Drug Stores                20
# Aerospace & Defense               14
# Food, Beverages & Tobacco         16
# Household Products                 3
# Transportation                    19
# Materials                         16
# Chemicals                          7
# Media                              3
# Apparel                            2
# ...

# %%
for media,i in f500.iterrows():
    if i["sector"] == "Media":
        print(i.values)
# Out:
# ['Disney' 161 55632 6.0 9391.0 92033 12.0 'Robert A. Iger' 'Entertainment'
#  'Media' 164 'USA' 'Burbank, CA' 'http://www.disney.com' 23 195000 43265]
# ['Time Warner' 371 29318 4.3 3926.0 65966 2.4 'Jeffrey L. Bewkes'
#  'Entertainment' 'Media' 376 'USA' 'New York, NY'
#  'http://www.timewarner.com' 16 25000 24335]
# ['Twenty-First Century Fox' 396 27326 -5.7 2755.0 48365 -66.8
#  'James R. Murdoch' 'Entertainment' 'Media' 360 'USA' 'New York, NY'
#  'http://www.21cf.com' 23 21500 13661]

# %%
f500[f500['sector'] == "Media"]
# Out:
#                       company  rank  revenues  revenue_change  profits  \
# 160                    Disney   161     55632             6.0   9391.0
# 370               Time Warner   371     29318             4.3   3926.0
# 395  Twenty-First Century Fox   396     27326            -5.7   2755.0
#
#      assets  profit_change                ceo       industry sector  \
# 160   92033           12.0     Robert A. Iger  Entertainment  Media
# 370   65966            2.4  Jeffrey L. Bewkes  Entertainment  Media
# 395   48365          -66.8   James R. Murdoch  Entertainment  Media
#
#      previous_rank country   hq_location                    website  \
# 160            164     USA   Burbank, CA      http://www.disney.com
# 370            376     USA  New York, NY  http://www.timewarner.com
# 395            360     USA  New York, NY        http://www.21cf.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# ...

# %%
f500.loc[f500["country"] == "China", ["company","ceo"]]
# Out:
#                                    company            ceo
# 1                               State Grid        Kou Wei
# 2                            Sinopec Group      Wang Yupu
# 3                 China National Petroleum  Zhang Jianhua
# 21   Industrial & Commercial Bank of China         Gu Shu
# 23    China State Construction Engineering      Guan Qing
# ..                                     ...            ...
# 487                             Xiamen C&D  Huang Wenzhou
# 489               China General Technology    Xu Xianping
# 493               Xiamen ITG Holding Group      Xu Xiaoxi
# 494  Xinjiang Guanghui Industry Investment  Shang Jiqiang
# 496               New China Life Insurance       Wan Feng
#
# [109 rows x 2 columns]

# %%
f500['country'].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
for taiwan,i in f500.iterrows():
    if i['country'] == "Mexico":
        print(i.values)
# Out:
# ['Pemex' 152 57774 -21.4 -10256.3 113115 nan 'Jose Antonio Gonzalez Anaya'
#  'Mining, Crude-Oil Production' 'Energy' 98 'Mexico' 'Mexico City, Mexico'
#  'http://www.pemex.com' 23 125689 -59909]
# ['America Movil' 176 52201 -7.4 462.9 73555 -79.0 'Daniel Hajj Aboumrad'
#  'Telecommunications' 'Telecommunications' 154 'Mexico'
#  'Mexico City, Mexico' 'http://www.americamovil.com' 11 194193 10143]

# %%
f500['country'] == 'USA'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: country, Length: 500, dtype: bool

# %%
f500[f500['country'] == 'Mexico']
# Out:
#            company  rank  revenues  revenue_change  profits  assets  \
# 151          Pemex   152     57774           -21.4 -10256.3  113115
# 175  America Movil   176     52201            -7.4    462.9   73555
#
#      profit_change                          ceo                      industry  \
# 151            NaN  Jose Antonio Gonzalez Anaya  Mining, Crude-Oil Production
# 175          -79.0         Daniel Hajj Aboumrad            Telecommunications
#
#                  sector  previous_rank country          hq_location  \
# 151              Energy             98  Mexico  Mexico City, Mexico
# 175  Telecommunications            154  Mexico  Mexico City, Mexico
#
#                          website  years_on_global_500_list  employees  \
# 151         http://www.pemex.com                        23     125689
# 175  http://www.americamovil.com                        11     194193
#
#      total_stockholder_equity
# 151                    -59909
# 175                     10143

# %%
f500.loc[f500['country'] == 'Mexico' , ['ceo' ,'industry']]
# Out:
#                              ceo                      industry
# 151  Jose Antonio Gonzalez Anaya  Mining, Crude-Oil Production
# 175         Daniel Hajj Aboumrad            Telecommunications

# %%
f500.loc[f500['sector'] == 'Chemicals', ['country' ,'company']]
# Out:
#           country                       company
# 125       Germany                          BASF
# 195           USA                  Dow Chemical
# 210         China                     ChemChina
# 298  Saudi Arabia                         SABIC
# 348         Japan  Mitsubishi Chemical Holdings
# 373   Netherlands     LyondellBasell Industries
# 437           USA                        DuPont

# %%
f500[f500['sector'] == 'Chemicals']
# Out:
#                           company  rank  revenues  revenue_change  profits  \
# 125                          BASF   126     63641           -18.6   4485.3
# 195                  Dow Chemical   196     48158            -1.3   4318.0
# 210                     ChemChina   211     45177             9.1     17.9
# 298                         SABIC   299     35421           -10.3   4757.1
# 348  Mitsubishi Chemical Holdings   349     31158             5.6   1442.1
# 373     LyondellBasell Industries   374     29183           -10.9   3836.0
# 437                        DuPont   438     24594           -12.0   2513.0
#
#      assets  profit_change                        ceo   industry     sector  \
# 125   80675            1.4               Kurt W. Bock  Chemicals  Chemicals
# 195   79511          -43.8          Andrew N. Liveris  Chemicals  Chemicals
# 210   54341            NaN                Ren Jianxin  Chemicals  Chemicals
# ...

# %%
f500["sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Motor Vehicles & Parts', 'Financials',
#        'Technology', 'Wholesalers', 'Health Care', 'Telecommunications',
#        'Engineering & Construction', 'Industrials', 'Food & Drug Stores',
#        'Aerospace & Defense', 'Food, Beverages & Tobacco',
#        'Household Products', 'Transportation', 'Materials', 'Chemicals',
#        'Media', 'Apparel', 'Hotels, Restaurants & Leisure',
#        'Business Services'], dtype=object)

# %%
f500['country'].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
f500['industry'].value_counts()
# Out:
# Banks: Commercial and Savings                     51
# Motor Vehicles and Parts                          34
# Petroleum Refining                                28
# Insurance: Life, Health (stock)                   24
# Food and Drug Stores                              20
# Mining, Crude-Oil Production                      18
# Telecommunications                                18
# Utilities                                         18
# Insurance: Property and Casualty (Stock)          18
# Trading                                           15
# Pharmaceuticals                                   15
# Aerospace and Defense                             14
# Electronics, Electrical Equip.                    13
# Engineering, Construction                         13
# Energy                                            12
# Metals                                            12
# Industrial Machinery                              10
# Specialty Retailers                               10
# ...

# %%
frq_table = pd.Series()

for i in f500['industry']:
    if i not in frq_table:
        frq_table[i] = 1
    else:
        frq_table[i] += 1

frq_table
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_2352\1911090846.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_table = pd.Series()
# General Merchandisers                              7
# Utilities                                         18
# Petroleum Refining                                28
# Motor Vehicles and Parts                          34
# Insurance: Property and Casualty (Stock)          18
# Computers, Office Equipment                        8
# Wholesalers: Health Care                           6
# Health Care: Insurance and Managed Care            6
# Health Care: Pharmacy and Other Services           2
# Electronics, Electrical Equip.                    13
# Mining, Crude-Oil Production                      18
# Telecommunications                                18
# Diversified Financials                             8
# ...

# %%
for apparel, i in f500.iterrows():
    if i['industry'] == 'Apparel':
        print(i.values)
# Out:
# ['Christian Dior' 234 42113 0.5 1740.3 69870 -38.7 'Sidney Toledano'
#  'Apparel' 'Apparel' 228 'France' 'Paris, France'
#  'http://www.dior-finance.com' 17 120479 12293]
# ['Nike' 331 32376 5.8 3760.0 21396 14.9 'Mark G. Parker' 'Apparel'
#  'Apparel' 343 'USA' 'Beaverton, OR' 'http://www.nike.com' 11 70700 12258]

# %%
f500[f500['industry'] == "Apparel"]
# Out:
#             company  rank  revenues  revenue_change  profits  assets  \
# 233  Christian Dior   234     42113             0.5   1740.3   69870
# 330            Nike   331     32376             5.8   3760.0   21396
#
#      profit_change              ceo industry   sector  previous_rank country  \
# 233          -38.7  Sidney Toledano  Apparel  Apparel            228  France
# 330           14.9   Mark G. Parker  Apparel  Apparel            343     USA
#
#        hq_location                      website  years_on_global_500_list  \
# 233  Paris, France  http://www.dior-finance.com                        17
# 330  Beaverton, OR          http://www.nike.com                        11
#
#      employees  total_stockholder_equity
# 233     120479                     12293
# 330      70700                     12258

# %%
f500.loc[f500['industry'] == 'Apparel' , ['ceo' ,'sector' , 'industry']]
# Out:
#                  ceo   sector industry
# 233  Sidney Toledano  Apparel  Apparel
# 330   Mark G. Parker  Apparel  Apparel

# %%
f500['country'].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
f500[(f500["country"] == "USA") & (f500["sector"] == "Technology")]
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 8                         Apple     9    215639            -7.7  45687.0
# 25                   Amazon.com    26    135987            27.1   2371.0
# 64                     Alphabet    65     90272            20.4  19478.0
# 68                    Microsoft    69     85320            -8.8  16798.0
# 80                          IBM    81     79919            -3.1  11872.0
# 123           Dell Technologies   124     64806            18.1  -1672.0
# 143                       Intel   144     59387             7.3  10316.0
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
# 186               Cisco Systems   187     49247             0.2  10739.0
# 193                          HP   194     48238           -53.3   2496.0
# 259     Honeywell International   260     39302             1.9   4809.0
# 279                      Oracle   280     37047            -3.1   8901.0
# ...

# %%
bool_india = f500['country'] == 'India'
bool_india
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: country, Length: 500, dtype: bool

# %%
f500.loc[f500['country'] == 'India', ['ceo' , 'industry' ,'country']]
# Out:
#                         ceo                       industry country
# 167            Sanjiv Singh             Petroleum Refining   India
# 202        Mukesh D. Ambani             Petroleum Refining   India
# 216  Arundhati Bhattacharya  Banks: Commercial and Savings   India
# 246        Guenter Butschek       Motor Vehicles and Parts   India
# 294         Rajesh J. Mehta                        Trading   India
# 359             D. Rajkumar             Petroleum Refining   India
# 383     Mukesh Kumar Surana             Petroleum Refining   India

# %%
coun_sec = f500[(f500['country'] == 'India') & (f500['sector'] == "Petroleum Refining")]
coun_sec
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
usa_tech = f500[(f500["country"] == "USA") & (f500["sector"] == "Technology")]

# %%
usa_tech
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 8                         Apple     9    215639            -7.7  45687.0
# 25                   Amazon.com    26    135987            27.1   2371.0
# 64                     Alphabet    65     90272            20.4  19478.0
# 68                    Microsoft    69     85320            -8.8  16798.0
# 80                          IBM    81     79919            -3.1  11872.0
# 123           Dell Technologies   124     64806            18.1  -1672.0
# 143                       Intel   144     59387             7.3  10316.0
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
# 186               Cisco Systems   187     49247             0.2  10739.0
# 193                          HP   194     48238           -53.3   2496.0
# 259     Honeywell International   260     39302             1.9   4809.0
# 279                      Oracle   280     37047            -3.1   8901.0
# ...

# %%
coun_sec = f500[( f500["country"] == "India" ) & ( f500["sector"] == "Petroleum Refining" )]
coun_sec
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
f500[(f500["country"] == "USA" ) & (f500["sector"] == "Technology" )]
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 8                         Apple     9    215639            -7.7  45687.0
# 25                   Amazon.com    26    135987            27.1   2371.0
# 64                     Alphabet    65     90272            20.4  19478.0
# 68                    Microsoft    69     85320            -8.8  16798.0
# 80                          IBM    81     79919            -3.1  11872.0
# 123           Dell Technologies   124     64806            18.1  -1672.0
# 143                       Intel   144     59387             7.3  10316.0
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
# 186               Cisco Systems   187     49247             0.2  10739.0
# 193                          HP   194     48238           -53.3   2496.0
# 259     Honeywell International   260     39302             1.9   4809.0
# 279                      Oracle   280     37047            -3.1   8901.0
# ...

# %%
f500['country'].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
f500['country'] == 'China'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: country, Length: 500, dtype: bool

# %%
f500.loc[f500["country"] == "China" , ['sector' , 'country']]
# Out:
#                      sector country
# 0                 Retailing   China
# 1                    Energy   China
# 2                    Energy   China
# 3                    Energy   China
# 4    Motor Vehicles & Parts   China
# ..                      ...     ...
# 495             Health Care   China
# 496              Financials   China
# 497      Food & Drug Stores   China
# 498       Business Services   China
# 499               Retailing   China
#
# [500 rows x 2 columns]

# %%
f500[(f500["country"] == "USA" ) & (f500['sector'] == 'Technology')]
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
f500[(f500["country"] == "USA" ) & (f500["sector"] == "Technology" )]
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
f500[(f500["country"] == "USA" ) & (f500["sector"] == "Technology" )]
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
f500['country'] == "India"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: country, Length: 500, dtype: bool

# %%
f500.loc[f500["country"] == 'India' , ['sector' , 'rank']]
# Out:
# Empty DataFrame
# Columns: [sector, rank]
# Index: []
